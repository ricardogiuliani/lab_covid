# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_dataset/covid_rs_20210101.csv', sep=';')

# %%
df = df[df.eq('OBITO').any(axis=1)]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
for idx, row in df.iterrows():
    if  df.loc[idx,'CRITERIO'] == 'Clínico-Imagem' or df.loc[idx,'CRITERIO'] == 'Clínico Epidemiológico' or df.loc[idx,'CRITERIO'] == 'Outros testes' or df.loc[idx,'CRITERIO'] == 'Outros Testes' or df.loc[idx,'CRITERIO'] == 'Clínico' or df.loc[idx,'CRITERIO'] == 'Ignorado':
        df.loc[idx,'CRITERIO'] = 'Outros'
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-11-21a3c5c45032>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[idx,'CRITERIO'] = 'Outros'

# %%
df.to_csv('pp_dataset/covid_rs_20210101.csv', sep=';', index=None)

# %%
df.head()

# %%
df.CRITERIO.unique()

# %%
for index, row in df.iterrows():
    if row['FAIXAETARIA'] == '<1':
        row['FAIXAETARIA'] = 'Bebê'
    elif row['FAIXAETARIA'] == '01 a 04' or row['FAIXAETARIA'] == '05 a 09':
        row['FAIXAETARIA'] = 'Criança'
    elif row['FAIXAETARIA'] == '10 a 14' or row['FAIXAETARIA'] == '15 a 19':
        row['FAIXAETARIA'] = 'Jovem'
    elif row['FAIXAETARIA'] == '20 a 29' or row['FAIXAETARIA'] == '30 a 39':
        row['FAIXAETARIA'] = 'Adulto_1'
    elif row['FAIXAETARIA'] == '40 a 49':
        row['FAIXAETARIA'] = 'Adulto_2'
    elif row['FAIXAETARIA'] == '50 a 59':
        row['FAIXAETARIA'] = 'Adulto_3'
    elif row['FAIXAETARIA'] == '60 a 69':
        row['FAIXAETARIA'] = 'Idoso_1'
    elif row['FAIXAETARIA'] == '70 a 79':
        row['FAIXAETARIA'] = 'Idoso_2'
    else:
        row['FAIXAETARIA'] = 'Idoso_3'

# %%
df = pd.read_csv('rs_hosp.csv', sep=';')

# %%
df = pd.read_csv('sc_hosp.csv', sep=';')

# %%
df = pd.pivot_table(df, values=['confirmed'], index=['date'], aggfunc=np.sum)

# %%
df.to_csv('evo_sc.csv')

# %%
df
# Out:
#                      REGIAO_COVID       SEXO FAIXAETARIA CRITERIO  \
# 97      PASSO FUNDO - R17 R18 R19  Masculino     Idoso_3   RT-PCR
# 136     PASSO FUNDO - R17 R18 R19   Feminino     Idoso_3   RT-PCR
# 169     PASSO FUNDO - R17 R18 R19  Masculino     Idoso_3   RT-PCR
# 189     PASSO FUNDO - R17 R18 R19   Feminino    Adulto_3   RT-PCR
# 202     PASSO FUNDO - R17 R18 R19  Masculino     Idoso_2   RT-PCR
# ...                           ...        ...         ...      ...
# 451822   CAPAO DA CANOA - R04 R05   Feminino     Idoso_1   RT-PCR
# 451842   CAPAO DA CANOA - R04 R05   Feminino     Idoso_2   RT-PCR
# 451860   CAPAO DA CANOA - R04 R05   Feminino     Idoso_1   RT-PCR
# 451869   CAPAO DA CANOA - R04 R05   Feminino     Idoso_1   RT-PCR
# 451910   CAPAO DA CANOA - R04 R05  Masculino     Idoso_1   RT-PCR
#
#        DATA_CONFIRMACAO DATA_EVOLUCAO HOSPITALIZADO FEBRE TOSSE GARGANTA  \
# 97           03/12/2020    20/12/2020           SIM   SIM   SIM      NAO
# 136          25/11/2020    11/12/2020           SIM   NAO   SIM      NAO
# 169          21/11/2020    22/11/2020           NAO   NAO   SIM      NAO
# 189          23/08/2020    01/09/2020           SIM   SIM   SIM      SIM
# 202          27/08/2020    19/10/2020           SIM   SIM   SIM      NAO
# ...                 ...           ...           ...   ...   ...      ...
# 451822       19/06/2020    23/06/2020           SIM   NAO   NAO      NAO
# 451842       11/07/2020    17/07/2020           SIM   NAO   SIM      NAO
# 451860       28/07/2020    18/08/2020           SIM   SIM   SIM      NAO
# 451869       08/08/2020    22/08/2020           SIM   NAO   NAO      NAO
# 451910       21/12/2020    25/12/2020           NAO   SIM   SIM      NAO
#
#        DISPNEIA OUTROS                                          CONDICOES  \
# 97          SIM    NAO                      Doença Cardiovascular Crônica
# 136         SIM    SIM                      Doença Cardiovascular Crônica
# 169         SIM    NAO                                             Outros
# 189         SIM    NAO   Doença Cardiovascular Crônica, Obesidade, Outros
# 202         SIM    NAO                      Doença Cardiovascular Crônica
# ...         ...    ...                                                ...
# 451822      SIM    SIM  Doença Cardiovascular Crônica, Doença Hematoló...
# 451842      SIM    SIM                                                NaN
# 451860      SIM    NAO   Doença Cardiovascular Crônica, Diabetes mellitus
# 451869      NAO    NAO   Doença Cardiovascular Crônica, Diabetes mellitus
# 451910      SIM    NAO                           Imunodeficiência, Outros
#
#        GESTANTE DATA_INCLUSAO_OBITO       RACA_COR HOSPITALIZACAO_SRAG
# 97          NAO          21/12/2020         BRANCA                 SIM
# 136         NAO          13/12/2020         BRANCA                 SIM
# 169         NAO          25/11/2020  NAO INFORMADO                 SIM
# 189         NAO          02/09/2020         BRANCA                 SIM
# 202         NAO          19/10/2020         BRANCA                 SIM
# ...         ...                 ...            ...                 ...
# 451822      NAO          24/06/2020         BRANCA                 SIM
# 451842      NAO          18/07/2020  NAO INFORMADO                 SIM
# 451860      NAO          20/08/2020         BRANCA                 SIM
# 451869      NAO          25/08/2020         BRANCA                 SIM
# 451910      NAO          30/12/2020  NAO INFORMADO                 SIM
#
# [8917 rows x 17 columns]

# %%
df.CRITERIO.unique()
# Out:
# array(['RT-PCR', 'TESTE RÁPIDO', 'Outros'], dtype=object)
